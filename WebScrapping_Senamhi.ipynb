# %%
# !pip install beautifulsoup4==4.12.3 certifi==2024.2.2 charset-normalizer==3.3.2 et-xmlfile==1.1.0 idna==3.6 lxml==5.1.0 numpy==1.26.4 openpyxl==3.1.2 pandas==2.2.0 python-dateutil==2.8.2 pytz==2024.1 requests==2.31.0 six==1.16.0 soupsieve==2.5 tzdata==2024.1 urllib3==2.2.0
# Out:
# Requirement already satisfied: beautifulsoup4==4.12.3 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Collecting certifi==2024.2.2
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting et-xmlfile==1.1.0
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting idna==3.6
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting lxml==5.1.0
#   Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting openpyxl==3.1.2
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas==2.2.0
#   Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Collecting pytz==2024.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests==2.31.0
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting soupsieve==2.5
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting tzdata==2024.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.2.0
#   Downloading urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 6.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 9.3 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.4 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 70.0 MB/s eta 0:00:00
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 13.9 MB/s eta 0:00:00
# Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 82.0 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 23.2 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.0 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 18.6 MB/s eta 0:00:00
# Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: pytz, urllib3, tzdata, soupsieve, six, lxml, idna, et-xmlfile, charset-normalizer, certifi, requests, openpyxl, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.2
#     Uninstalling tzdata-2024.2:
#       Successfully uninstalled tzdata-2024.2
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.6
#     Uninstalling soupsieve-2.6:
#       Successfully uninstalled soupsieve-2.6
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.0
#     Uninstalling lxml-5.3.0:
#       Successfully uninstalled lxml-5.3.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: et-xmlfile
#     Found existing installation: et_xmlfile 2.0.0
#     Uninstalling et_xmlfile-2.0.0:
#       Successfully uninstalled et_xmlfile-2.0.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.0
#     Uninstalling charset-normalizer-3.4.0:
#       Successfully uninstalled charset-normalizer-3.4.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.12.14
#     Uninstalling certifi-2024.12.14:
#       Successfully uninstalled certifi-2024.12.14
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.5
#     Uninstalling openpyxl-3.1.5:
#       Successfully uninstalled openpyxl-3.1.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 et-xmlfile-1.1.0 idna-3.6 lxml-5.1.0 openpyxl-3.1.2 pandas-2.2.0 pytz-2024.1 requests-2.31.0 six-1.16.0 soupsieve-2.5 tzdata-2024.1 urllib3-2.2.0

# %%
import pkg_resources

libraries = [
    'beautifulsoup4', 'certifi', 'charset-normalizer', 'et-xmlfile', 'idna',
    'lxml', 'numpy', 'openpyxl', 'pandas', 'python-dateutil', 'pytz',
    'requests', 'six', 'soupsieve', 'tzdata', 'urllib3'
]

for lib in libraries:
    try:
        version = pkg_resources.get_distribution(lib).version
        print(f"{lib}: {version} (instalado correctamente)")
    except pkg_resources.DistributionNotFound:
        print(f"{lib}: No se encontró la librería")
# Out:
# beautifulsoup4: 4.12.3 (instalado correctamente)
# certifi: 2024.2.2 (instalado correctamente)
# charset-normalizer: 3.3.2 (instalado correctamente)
# et-xmlfile: 1.1.0 (instalado correctamente)
# idna: 3.6 (instalado correctamente)
# lxml: 5.1.0 (instalado correctamente)
# numpy: 1.26.4 (instalado correctamente)
# openpyxl: 3.1.2 (instalado correctamente)
# pandas: 2.2.0 (instalado correctamente)
# python-dateutil: 2.8.2 (instalado correctamente)
# pytz: 2024.1 (instalado correctamente)
# requests: 2.31.0 (instalado correctamente)
# six: 1.16.0 (instalado correctamente)
# soupsieve: 2.5 (instalado correctamente)
# tzdata: 2024.1 (instalado correctamente)
# urllib3: 2.2.0 (instalado correctamente)
# <ipython-input-1-f16c484b3725>:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import os
import re

def stations():
    link = "https://www.senamhi.gob.pe/mapas/mapa-estaciones-2/"
    response = requests.get(link)
    stn_senamhi = BeautifulSoup(response.text, 'html.parser')

    stn_senamhi2 = re.split(r'nom', str(stn_senamhi))[1:]
    stn = []
    cat = []
    lat = []
    lon = []
    ico = []
    cod = []
    cod_old = []
    estado = []
    data_stn = []

    for i in range(len(stn_senamhi2)):
        x = stn_senamhi2[i].replace('"', '').replace(': ', ":").replace(',\n', "").replace('\\}\{', "")
        data_estaciones = x.split(",")
        stn.append(data_estaciones[0].replace(":", ""))
        cat.append(data_estaciones[1].replace("cate:", ""))
        lat.append(data_estaciones[2].replace("lat:", ""))
        lon.append(data_estaciones[3].replace("lon:", ""))
        ico.append(data_estaciones[4].replace(" ico:", ""))
        cod.append(data_estaciones[5].replace(" cod:", "") if data_estaciones[5][:5] == " cod:" else None)
        cod_old.append(data_estaciones[6].replace("cod_old:", "") if data_estaciones[6][:8] == "cod_old:" else None)
        estado_value = data_estaciones[7] if len(data_estaciones) > 7 else data_estaciones[6]
        estado.append(estado_value.replace("}{", "").replace(" estado:", "") if estado_value[:8] == " estado:" else None)

        data_stn.append(pd.DataFrame({
            'estacion': stn[-1],
            'categoria': cat[-1],
            'lat': lat[-1],
            'lon': lon[-1],
            'ico': ico[-1],
            'cod': cod[-1],
            'cod_old': cod_old[-1],
            'estado': estado[-1]
        }, index=[0]))

    df_stns = pd.concat(data_stn, ignore_index=True)
    return df_stns

def senamhiws_info(code, stations, from_date=None, to_date=None, lat=None, lon=None, stc=None):
    if not code or not isinstance(code, str):
        print("Codigo no definido")
        return None

    df_history_senamhi = []

    if from_date is None and to_date is None:
        from_date = datetime(2016, 1, 1)
        to_date = datetime(2023, 12, 31)
    elif from_date is None and to_date is not None:
        from_date = datetime(2016, 1, 1)
    elif from_date is not None and to_date is None:
        to_date = datetime(2023, 12, 31)

    idx_cod = stations.index[stations['cod'] == code]
    df_idx_stn = stations.loc[idx_cod].reset_index(drop=True)

    ts_date = pd.date_range(from_date, to_date, freq='MS')
    tsw_date = ts_date.strftime('%Y%m')

    for j, date in enumerate(ts_date):
        if pd.isna(df_idx_stn['cod'][0]):
            link = f"https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones={df_idx_stn['cod'].iloc[0]}&CBOFiltro={tsw_date[j]}&t_e={df_idx_stn['ico'].iloc[0]}&estado={df_idx_stn['estado'].iloc[0]}&cod_old={df_idx_stn['cod_old'].iloc[0]}"
        else:
            link = f"https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones={df_idx_stn['cod'].iloc[0]}&CBOFiltro={tsw_date[j]}&t_e={df_idx_stn['ico'].iloc[0]}&estado={df_idx_stn['estado'].iloc[0]}"

        try:
            print(f"Descargando datos desde: {link}")
            data_stn_senamhi = pd.read_html(link)
        except ValueError as e:
            print(f"Error al leer HTML desde el enlace: {e}")
            print(f"El enlace que falló es: {link}")
            continue

        # Procesar los datos descargados
        data_df_history_senamhi = data_stn_senamhi[1]
        data_df_history_senamhi.columns = data_df_history_senamhi.iloc[0]
        data_df_history_senamhi = data_df_history_senamhi[1:]

        # Eliminar filas que contienen los encabezados repetidos
        data_df_history_senamhi = data_df_history_senamhi[data_df_history_senamhi.iloc[:, 0] != 'AÑO / MES / DÍA']

        # Añadir información adicional
        data_df_history_senamhi["estacion"] = stc
        data_df_history_senamhi["lat"] = lat
        data_df_history_senamhi["lon"] = lon

        # Añadir los datos al historial
        df_history_senamhi.append(data_df_history_senamhi)

    # Combinar todos los datos descargados en un único DataFrame
    if df_history_senamhi:
        df_combined = pd.concat(df_history_senamhi, ignore_index=True)
        output_filename = f"{code}_{df_idx_stn['estacion'].iloc[0]}_historico.xlsx"
        df_combined.to_excel(output_filename, index=False)
        print(f"Datos combinados guardados en: {output_filename}")
    else:
        print("No se encontraron datos para la estación especificada.")

    return df_history_senamhi

# %% [markdown]
# #USO DEL CODIGO

# %%
# Uso del código
stations_data = stations()
print(stations_data[stations_data["estacion"] == 'ANANEA'])
# Out:
#     estacion categoria        lat        lon ico     cod cod_old estado
# 566   ANANEA        CO   -14.6763   -69.5339   M  114050    None   REAL

# %%
# Filtrar datos de la estación específica
stations_data = stations()

stations_data = stations_data[stations_data["cod"] == '4728C78C']
print("aaaaa", stations_data.head())
# Out:
# aaaaa        estacion categoria         lat     lon ico       cod cod_old  \
# 703  CUSICANCHA       EMA   -13.48333   -75.3   M  4728C78C    None
#
#          estado
# 703  AUTOMATICA

# %%
#Este codigo descarga los datos de la estacion definida anteriormente y los combina en un solo archivo excel
# Convertir latitud y longitud a números
stations_data['lat'] = pd.to_numeric(stations_data['lat'], errors='coerce')
stations_data['lon'] = pd.to_numeric(stations_data['lon'], errors='coerce')

lat = stations_data['lat'].tolist()[0]
lon = stations_data['lon'].tolist()[0]
stc = stations_data['estacion'].tolist()[0]
codigo = stations_data['cod'].tolist()[0]
print('codigo', codigo)

print("values", lat, lon, stc)

# Llamar a la función para obtener datos históricos
try:
    resultados = senamhiws_info(codigo, stations_data, '2015-01-01', '2024-09-30', lat, lon, stc)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# codigo 4728C78C
# values -13.48333 -75.3 CUSICANCHA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201501&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201502&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201503&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201504&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201505&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201506&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201507&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201508&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201509&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201510&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201511&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201512&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201601&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201602&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201603&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201604&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201605&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201606&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201607&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201608&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201609&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201610&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201611&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201612&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201701&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201702&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201703&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201704&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201705&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201706&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201707&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201708&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201709&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201710&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201711&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201712&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201801&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201802&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201803&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201804&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201805&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201806&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201807&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201808&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201809&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201810&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201811&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201812&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201901&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201902&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201903&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201904&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201905&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201906&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201907&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201908&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201909&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201910&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201911&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=201912&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202001&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202002&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202003&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202004&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202005&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202006&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202007&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202008&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202009&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202010&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202011&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202012&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202101&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202102&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202103&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202104&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202105&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202106&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202107&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202108&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202109&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202110&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202111&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202112&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202201&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202202&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202203&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202204&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202205&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202206&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202207&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202208&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202209&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202210&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202211&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202212&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202301&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202302&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202303&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202304&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202305&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202306&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202307&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202308&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202309&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202310&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202311&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202312&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202401&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202402&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202403&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202404&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202405&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202406&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202407&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202408&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=4728C78C&CBOFiltro=202409&t_e=M&estado=AUTOMATICA
# Datos combinados guardados en: 4728C78C_CUSICANCHA_historico.xlsx
